# %% [markdown]
# # Chapter 2 problem 2.3:Aliasing

# %% [markdown]
# Problem 2.3:
# Execute the command plot(sin(1 :3000),'. ') in MATLAB. What do
# you see? What does this have to do with aliasing? Give a quantitative answer,
# explaining exactly what frequency is being aliased by your eye and brain to what
# other frequency. Then, for fun, replace 3000 by 1000 to get a figure somewhat
# harder to explain.

# %%
from numpy import arange,maximum,abs,zeros,sin,pi
from matplotlib.pyplot import subplot,figure,plot,grid,axis

# %%
a = np.arange(1,3001)
b = np.arange(1,1001)
# = np.arange(1,101)


figure(figsize(10, 10))
figure(1)
plot(sin(a),"*")
title(" Fig-1 : sin(x) with x ranging from 1:3000")
figure(2)
plot(sin(b),".")
title(" Fig-2: sin(x) with x ranging from 1:1000")

# %% [markdown]
# In Figure.1 a quantitative aliasing of frequencies can be seen more clearly,in comparison to the Figure-2 because of less number of points used.Figure 1 intersections of the two curves correspondes to the aliasing frequency  where the values on the y-axis closely matches to each other,while in case of Figure 2 predicting the accurate intersction of the curve is less because of less number of points used for computing the curve.
